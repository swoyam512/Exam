# %% [markdown]
# # Swoyam Maharjan
#
# **Course:** BSc. Computing
# **Student ID / Email:** 77683906 / mswoyam24@tbc.edu.np
#
# I am submitting Exam paper 2.

# %% [markdown]
# ## How I Work Best in Programming
# ### My approach
#  I work best in programming when I have a **quiet and focused environment** with minimal distractions. I prefer working in short, concentrated sessions and taking small breaks to stay productive,
#
# ### Tools and Environment
# "I enjoy using simple and efficient tools" that help me concentrate on logic rather than setup. My most preferred tools include:
# **VS Code** for writing structured codes.
# **Jupyter Notebooks** for testing few ideas.
# Online documentation for quick references
#
# ### Learning styles
# I learn best by **practicing**, making mistakes, and fixing them. And, I like improving my solutions step by step.
